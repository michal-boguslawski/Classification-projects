# %%
# !pip install -q pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
link = "C:\\Users\\bogus\\PycharmProjects\\Classification Projects\\GiveLife\\data\\transfusion.data"
df = pd.read_csv(link)
df["New Column"] = (df["Time (months)"] - df["Recency (months)"]) / df["Frequency (times)"]
df["New Column2"] = df["Frequency (times)"] / df["Time (months)"]
df.head()
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0                 2                 50                  12500             98
# 1                 0                 13                   3250             28
# 2                 1                 16                   4000             35
# 3                 2                 20                   5000             45
# 4                 1                 24                   6000             77
#
#    whether he/she donated blood in March 2007  New Column  New Column2
# 0                                           1    1.920000     0.510204
# 1                                           1    2.153846     0.464286
# 2                                           1    2.125000     0.457143
# 3                                           1    2.150000     0.444444
# 4                                           0    3.166667     0.311688

# %%
len(df)
# Out:
# 748

# %%
df.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        748.000000         748.000000             748.000000
# mean           9.506684           5.514706            1378.676471
# std            8.095396           5.839307            1459.826781
# min            0.000000           1.000000             250.000000
# 25%            2.750000           2.000000             500.000000
# 50%            7.000000           4.000000            1000.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)  whether he/she donated blood in March 2007  New Column  \
# count     748.000000                                  748.000000  748.000000
# mean       34.282086                                    0.237968    4.332166
# std        24.376714                                    0.426124    4.774425
# ...

# %%
df[df["whether he/she donated blood in March 2007"] == 1].describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        178.000000         178.000000             178.000000
# mean           5.455056           7.797753            1949.438202
# std            5.170615           8.036892            2009.223005
# min            0.000000           1.000000             250.000000
# 25%            2.000000           3.000000             750.000000
# 50%            4.000000           6.000000            1500.000000
# 75%            4.750000           9.000000            2250.000000
# max           26.000000          50.000000           12500.000000
#
#        Time (months)  whether he/she donated blood in March 2007  New Column  \
# count     178.000000                                       178.0  178.000000
# mean       32.719101                                         1.0    3.585003
# std        23.629431                                         0.0    3.308278
# ...

# %%
df[df["whether he/she donated blood in March 2007"] == 0].describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        570.000000         570.000000             570.000000
# mean          10.771930           4.801754            1200.438596
# std            8.425039           4.746768            1186.692017
# min            0.000000           1.000000             250.000000
# 25%            4.000000           2.000000             500.000000
# 50%           11.000000           3.000000             750.000000
# 75%           16.000000           6.000000            1500.000000
# max           74.000000          44.000000           11000.000000
#
#        Time (months)  whether he/she donated blood in March 2007  New Column  \
# count     570.000000                                       570.0  570.000000
# mean       34.770175                                         0.0    4.565490
# std        24.605388                                         0.0    5.127608
# ...

# %%
df.isna().sum()
# Out:
# Recency (months)                              0
# Frequency (times)                             0
# Monetary (c.c. blood)                         0
# Time (months)                                 0
# whether he/she donated blood in March 2007    0
# New Column                                    0
# New Column2                                   0
# dtype: int64

# %%
sns.pairplot(df, 
             kind="kde",
             diag_kind="kde",
             hue="whether he/she donated blood in March 2007"
             )
plt.show()

# %% [markdown]
# Monetary and Frequency are perfectly correlated, so we can take one

# %%
df.corr()
# Out:
#                                             Recency (months)  \
# Recency (months)                                    1.000000
# Frequency (times)                                  -0.182745
# Monetary (c.c. blood)                              -0.182745
# Time (months)                                       0.160618
# whether he/she donated blood in March 2007         -0.279869
# New Column                                         -0.051441
# New Column2                                        -0.499594
#
#                                             Frequency (times)  \
# Recency (months)                                    -0.182745
# Frequency (times)                                    1.000000
# Monetary (c.c. blood)                                1.000000
# Time (months)                                        0.634940
# whether he/she donated blood in March 2007           0.218633
# New Column                                           0.031779
# ...
